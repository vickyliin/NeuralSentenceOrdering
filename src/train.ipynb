# %%
import pdb
from pairwise import Pairwise
# Out:
# Using gpu device 0: GeForce GTX TITAN X (CNMeM is disabled, cuDNN 5005)
# Using Theano backend.
# /nfs/nas-5.1/wrlin/story-reorder/NeuralSentenceOrdering/venv/local/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")

# %%
Pairwise(alpha=0.001, 
         batch_size=128, 
         n_epochs=20, 
         wordVecLen=100, 
         flag_dropout=False, 
         datapath='../data/vist.pkl.gz',
         random_seed=1234,
         dropoutRates=0.2,
         optimizer='adadelta',
         dispFreq=2048,
         beam_size=128,
         flag_random_lookup_table=False,
         flag_toy_data=False,
         size_hidden_layer=100,
         dataset='vist',
         result_path='./vist-result-1/',
         sentence_modeling='CNN', # CBoW, LSTM, CNN
         CNN_filter_length=3,
         LSTM_go_backwards=True)

# %%
Pairwise(alpha=0.0001, 
         batch_size=128, 
         n_epochs=20, 
         wordVecLen=100, 
         flag_dropout=False, 
         datapath='../data/vist.pkl.gz',
         random_seed=1234,
         dropoutRates=0.2,
         optimizer='adadelta',
         dispFreq=2048,
         beam_size=128,
         flag_random_lookup_table=False,
         flag_toy_data=False,
         size_hidden_layer=100,
         dataset='vist',
         result_path='./vist-result-2/',
         sentence_modeling='CNN', # CBoW, LSTM, CNN
         CNN_filter_length=3,
         LSTM_go_backwards=True)
# Out:
# Loading data
# Build model...
# Optimization
# 803100 train examples
# 99800 valid examples
# 101100 test examples
# Training on 0 epoch
# Epoch  0 Update  2048 Cost  0.545993567794 Samples_seen  262144
# Epoch  0 Update  4096 Cost  0.500460803923 Samples_seen  524288
# Epoch  0 Update  6144 Cost  0.523971039955 Samples_seen  786432
# Epoch  0 Update  6275 Cost  0.44619512232 Samples_seen  803100
# Valid_score:
# Top 1 beam
# patial_correct_rate:  0.729559118236
# total_correct_rate:  0.0859719438878
# Top 2 beam
# patial_correct_rate:  0.77627254509
# total_correct_rate:  0.167735470942
# Top 4 beam
# patial_correct_rate:  0.824649298597
# total_correct_rate:  0.285370741483
# Top 8 beam
# patial_correct_rate:  0.874228456914
# total_correct_rate:  0.442284569138
# Top 16 beam
# patial_correct_rate:  0.920581162325
# total_correct_rate:  0.615230460922
# Top 32 beam
# patial_correct_rate:  0.960160320641
# total_correct_rate:  0.785370741483
# Top 64 beam
# ...

# %%
Pairwise(alpha=0.00001, 
         batch_size=128, 
         n_epochs=20, 
         wordVecLen=100, 
         flag_dropout=False, 
         datapath='../data/vist.pkl.gz',
         random_seed=1234,
         dropoutRates=0.2,
         optimizer='adadelta',
         dispFreq=2048,
         beam_size=128,
         flag_random_lookup_table=False,
         flag_toy_data=False,
         size_hidden_layer=100,
         dataset='vist',
         result_path='./vist-result-3/',
         sentence_modeling='CNN', # CBoW, LSTM, CNN
         CNN_filter_length=3,
         LSTM_go_backwards=True)
# Out:
# Loading data
# Build model...
# Optimization
# 803100 train examples
# 99800 valid examples
# 101100 test examples
# Training on 0 epoch
# Epoch  0 Update  2048 Cost  0.511988621904 Samples_seen  262144
# Epoch  0 Update  4096 Cost  0.528725709184 Samples_seen  524288

# %%
Pairwise(alpha=1e-6, 
         batch_size=128, 
         n_epochs=20, 
         wordVecLen=100, 
         flag_dropout=False, 
         datapath='../data/vist.pkl.gz',
         random_seed=1234,
         dropoutRates=0.2,
         optimizer='adadelta',
         dispFreq=2048,
         beam_size=128,
         flag_random_lookup_table=False,
         flag_toy_data=False,
         size_hidden_layer=100,
         dataset='vist',
         result_path='./vist-result-4/',
         sentence_modeling='CNN', # CBoW, LSTM, CNN
         CNN_filter_length=3,
         LSTM_go_backwards=True)
# Out:
# Loading data
# Build model...
# Optimization
# 803100 train examples
# 99800 valid examples
# 101100 test examples
# Training on 0 epoch
# Epoch  0 Update  2048 Cost  0.523728698423 Samples_seen  262144
# Epoch  0 Update  4096 Cost  0.480209206709 Samples_seen  524288
# Epoch  0 Update  6144 Cost  0.480698459436 Samples_seen  786432
# Epoch  0 Update  6275 Cost  0.501959982727 Samples_seen  803100
# Valid_score:
# Top 1 beam
# patial_correct_rate:  0.733346693387
# total_correct_rate:  0.0931863727455
# Top 2 beam
# patial_correct_rate:  0.780080160321
# total_correct_rate:  0.174148296593
# Top 4 beam
# patial_correct_rate:  0.827595190381
# total_correct_rate:  0.287775551102
# Top 8 beam
# patial_correct_rate:  0.876312625251
# total_correct_rate:  0.444088176353
# Top 16 beam
# patial_correct_rate:  0.922625250501
# total_correct_rate:  0.620440881764
# Top 32 beam
# patial_correct_rate:  0.960601202405
# total_correct_rate:  0.793386773547
# Top 64 beam
# ...

# %%
Pairwise(alpha=1e-9, 
         batch_size=128, 
         n_epochs=20, 
         wordVecLen=100, 
         flag_dropout=False, 
         datapath='../data/vist.pkl.gz',
         random_seed=1234,
         dropoutRates=0.2,
         optimizer='adadelta',
         dispFreq=2048,
         beam_size=128,
         flag_random_lookup_table=False,
         flag_toy_data=False,
         size_hidden_layer=100,
         dataset='vist',
         result_path='./vist-result-5/',
         sentence_modeling='CNN', # CBoW, LSTM, CNN
         CNN_filter_length=3,
         LSTM_go_backwards=True)
# Out:
# Loading data
# Build model...
# Optimization
# 803100 train examples
# 99800 valid examples
# 101100 test examples
# Training on 0 epoch
# Epoch  0 Update  2048 Cost  0.501728081159 Samples_seen  262144
# Epoch  0 Update  4096 Cost  0.524008695564 Samples_seen  524288
# Epoch  0 Update  6144 Cost  0.448461611948 Samples_seen  786432
# Epoch  0 Update  6275 Cost  0.550056426453 Samples_seen  803100
# Valid_score:
# Top 1 beam
# patial_correct_rate:  0.734849699399
# total_correct_rate:  0.087374749499
# Top 2 beam
# patial_correct_rate:  0.781142284569
# total_correct_rate:  0.173547094188
# Top 4 beam
# patial_correct_rate:  0.829018036072
# total_correct_rate:  0.285971943888
# Top 8 beam
# patial_correct_rate:  0.878496993988
# total_correct_rate:  0.447294589178
# Top 16 beam
# patial_correct_rate:  0.923426853707
# total_correct_rate:  0.616633266533
# Top 32 beam
# patial_correct_rate:  0.961042084168
# total_correct_rate:  0.794589178357
# Top 64 beam
# ...

# %%
Pairwise(alpha=1e-2, 
         batch_size=128, 
         n_epochs=20, 
         wordVecLen=100, 
         flag_dropout=False, 
         datapath='../data/vist.pkl.gz',
         random_seed=1234,
         dropoutRates=0.2,
         optimizer='adadelta',
         dispFreq=2048,
         beam_size=128,
         flag_random_lookup_table=False,
         flag_toy_data=False,
         size_hidden_layer=100,
         dataset='vist',
         result_path='./vist-result-6/',
         sentence_modeling='CNN', # CBoW, LSTM, CNN
         CNN_filter_length=3,
         LSTM_go_backwards=True)
# Out:
# Loading data
# Build model...
# Optimization
# 803100 train examples
# 99800 valid examples
# 101100 test examples
# Training on 0 epoch
# Epoch  0 Update  2048 Cost  0.55848193643 Samples_seen  262144
# Epoch  0 Update  4096 Cost  0.431478768107 Samples_seen  524288
# Epoch  0 Update  6144 Cost  0.576707522785 Samples_seen  786432
# Epoch  0 Update  6275 Cost  0.525362276273 Samples_seen  803100
# Valid_score:
# Top 1 beam
# patial_correct_rate:  0.73126252505
# total_correct_rate:  0.0847695390782
# Top 2 beam
# patial_correct_rate:  0.7774749499
# total_correct_rate:  0.167935871743
# Top 4 beam
# patial_correct_rate:  0.826472945892
# total_correct_rate:  0.283366733467
# Top 8 beam
# patial_correct_rate:  0.876573146293
# total_correct_rate:  0.443486973948
# Top 16 beam
# patial_correct_rate:  0.922925851703
# total_correct_rate:  0.619639278557
# Top 32 beam
# patial_correct_rate:  0.960601202405
# total_correct_rate:  0.794789579158
# Top 64 beam
# ...

# %%
Pairwise(alpha=1e-2, 
         batch_size=128, 
         n_epochs=20, 
         wordVecLen=100, 
         flag_dropout=False, 
         datapath='../data/vist.pkl.gz',
         random_seed=1234,
         dropoutRates=0.2,
         optimizer='adadelta',
         dispFreq=2048,
         beam_size=128,
         flag_random_lookup_table=False,
         flag_toy_data=False,
         size_hidden_layer=100,
         dataset='vist',
         result_path='./vist-result-6/',
         sentence_modeling='LSTM', # CBoW, LSTM, CNN
         CNN_filter_length=3,
         LSTM_go_backwards=True)
# Out:
# Loading data
# Build model...
# Optimization
# 803100 train examples
# 99800 valid examples
# 101100 test examples
# Training on 0 epoch
# Epoch  0 Update  2048 Cost  0.615692887819 Samples_seen  262144
# Epoch  0 Update  4096 Cost  0.508866553711 Samples_seen  524288
# Epoch  0 Update  6144 Cost  0.449625317044 Samples_seen  786432
# Epoch  0 Update  6275 Cost  0.541284503848 Samples_seen  803100
# Valid_score:
# Top 1 beam
# patial_correct_rate:  0.744829659319
# total_correct_rate:  0.10380761523
# Top 2 beam
# patial_correct_rate:  0.79122244489
# total_correct_rate:  0.197995991984
# Top 4 beam
# patial_correct_rate:  0.836853707415
# total_correct_rate:  0.314428857715
# Top 8 beam
# patial_correct_rate:  0.885270541082
# total_correct_rate:  0.475951903808
# Top 16 beam
# patial_correct_rate:  0.928517034068
# total_correct_rate:  0.644889779559
# Top 32 beam
# patial_correct_rate:  0.964749498998
# total_correct_rate:  0.818236472946
# Top 64 beam
# ...
